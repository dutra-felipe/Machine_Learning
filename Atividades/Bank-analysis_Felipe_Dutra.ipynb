# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/bluenex/WekaLearningDataset/refs/heads/master/bank/bank-data.csv'
arquivo = pd.read_csv(url)
arquivo.head()
# Out:
#         id  age     sex      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO  YES
# 1         YES      YES   NO
# 2         YES       NO   NO
# 3         YES       NO   NO
# 4          NO       NO   NO

# %%
# Informações gerais sobre o dataset
print(arquivo.info())

# Descrição estatística das variáveis numéricas
print(arquivo.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           600 non-null    object
#  1   age          600 non-null    int64
#  2   sex          600 non-null    object
#  3   region       600 non-null    object
#  4   income       600 non-null    float64
#  5   married      600 non-null    object
#  6   children     600 non-null    int64
#  7   car          600 non-null    object
#  8   save_act     600 non-null    object
#  9   current_act  600 non-null    object
#  10  mortgage     600 non-null    object
#  11  pep          600 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 56.4+ KB
# None
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
#contador
print(arquivo['pep'].value_counts())
# Out:
# pep
# NO     326
# YES    274
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
arquivo.hist(figsize=(20, 15), bins=20)
plt.show()

# %%
arquivo.boxplot(figsize=(20, 10), rot=90)
plt.show()

# %%
# Check if 'pep' column exists in the DataFrame
if 'pep' in arquivo.columns:
    print("Column 'pep' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['pep'] = arquivo['pep'].replace('NO', 0)
    arquivo['pep'] = arquivo['pep'].replace('YES', 1)
else:
    print("Column 'pep' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'pep' exists in the DataFrame.
#         id  age     sex      region   income married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0      NO         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1     YES         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4     YES         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4     YES         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3     YES         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO    1
# 1         YES      YES    0
# 2         YES       NO    0
# 3         YES       NO    0
# 4          NO       NO    0
# /tmp/ipykernel_1964/1288954062.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['pep'] = arquivo['pep'].replace('YES', 1)

# %%
# Check if 'married' column exists in the DataFrame
if 'married' in arquivo.columns:
    print("Column 'married' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['married'] = arquivo['married'].replace('NO', 0)
    arquivo['married'] = arquivo['married'].replace('YES', 1)
else:
    print("Column 'married' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'married' exists in the DataFrame.
#         id  age     sex      region   income  married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0        0         1   NO       NO
# 1  ID12102   40    MALE        TOWN  30085.1        1         3  YES       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4        1         0  YES      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4        1         3   NO       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3        1         0   NO      YES
#
#   current_act mortgage  pep
# 0          NO       NO    1
# 1         YES      YES    0
# 2         YES       NO    0
# 3         YES       NO    0
# 4          NO       NO    0
# /tmp/ipykernel_1964/497722584.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['married'] = arquivo['married'].replace('YES', 1)

# %%
# Check if 'car' column exists in the DataFrame
if 'car' in arquivo.columns:
    print("Column 'car' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['car'] = arquivo['car'].replace('NO', 0)
    arquivo['car'] = arquivo['car'].replace('YES', 1)
else:
    print("Column 'car' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'car' exists in the DataFrame.
#         id  age     sex      region   income  married  children  car save_act  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0        0         1    0       NO
# 1  ID12102   40    MALE        TOWN  30085.1        1         3    1       NO
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4        1         0    1      YES
# 3  ID12104   23  FEMALE        TOWN  20375.4        1         3    0       NO
# 4  ID12105   57  FEMALE       RURAL  50576.3        1         0    0      YES
#
#   current_act mortgage  pep
# 0          NO       NO    1
# 1         YES      YES    0
# 2         YES       NO    0
# 3         YES       NO    0
# 4          NO       NO    0
# /tmp/ipykernel_1964/1462260696.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['car'] = arquivo['car'].replace('YES', 1)

# %%
# Check if 'save_act' column exists in the DataFrame
if 'save_act' in arquivo.columns:
    print("Column 'save_act' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['save_act'] = arquivo['save_act'].replace('NO', 0)
    arquivo['save_act'] = arquivo['save_act'].replace('YES', 1)
else:
    print("Column 'save_act' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'save_act' exists in the DataFrame.
#         id  age     sex      region   income  married  children  car  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0        0         1    0
# 1  ID12102   40    MALE        TOWN  30085.1        1         3    1
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4        1         0    1
# 3  ID12104   23  FEMALE        TOWN  20375.4        1         3    0
# 4  ID12105   57  FEMALE       RURAL  50576.3        1         0    0
#
#    save_act current_act mortgage  pep
# 0         0          NO       NO    1
# 1         0         YES      YES    0
# 2         1         YES       NO    0
# 3         0         YES       NO    0
# 4         1          NO       NO    0
# /tmp/ipykernel_1964/1658620841.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['save_act'] = arquivo['save_act'].replace('YES', 1)

# %%
# Check if 'current_act' column exists in the DataFrame
if 'current_act' in arquivo.columns:
    print("Column 'current_act' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['current_act'] = arquivo['current_act'].replace('NO', 0)
    arquivo['current_act'] = arquivo['current_act'].replace('YES', 1)
else:
    print("Column 'current_act' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'current_act' exists in the DataFrame.
#         id  age     sex      region   income  married  children  car  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0        0         1    0
# 1  ID12102   40    MALE        TOWN  30085.1        1         3    1
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4        1         0    1
# 3  ID12104   23  FEMALE        TOWN  20375.4        1         3    0
# 4  ID12105   57  FEMALE       RURAL  50576.3        1         0    0
#
#    save_act  current_act mortgage  pep
# 0         0            0       NO    1
# 1         0            1      YES    0
# 2         1            1       NO    0
# 3         0            1       NO    0
# 4         1            0       NO    0
# /tmp/ipykernel_1964/3135162528.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['current_act'] = arquivo['current_act'].replace('YES', 1)

# %%
# Check if 'mortgage' column exists in the DataFrame
if 'mortgage' in arquivo.columns:
    print("Column 'mortgage' exists in the DataFrame.")
    # Replace 'NO' with 0 and 'YES' with 1
    arquivo['mortgage'] = arquivo['mortgage'].replace('NO', 0)
    arquivo['mortgage'] = arquivo['mortgage'].replace('YES', 1)
else:
    print("Column 'mortgage' does not exist in the DataFrame.")

# Display the first few rows of the DataFrame
print(arquivo.head())
# Out:
# Column 'mortgage' exists in the DataFrame.
#         id  age     sex      region   income  married  children  car  \
# 0  ID12101   48  FEMALE  INNER_CITY  17546.0        0         1    0
# 1  ID12102   40    MALE        TOWN  30085.1        1         3    1
# 2  ID12103   51  FEMALE  INNER_CITY  16575.4        1         0    1
# 3  ID12104   23  FEMALE        TOWN  20375.4        1         3    0
# 4  ID12105   57  FEMALE       RURAL  50576.3        1         0    0
#
#    save_act  current_act  mortgage  pep
# 0         0            0         0    1
# 1         0            1         1    0
# 2         1            1         0    0
# 3         0            1         0    0
# 4         1            0         0    0
# /tmp/ipykernel_1964/92682938.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   arquivo['mortgage'] = arquivo['mortgage'].replace('YES', 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding para variáveis binárias
label_encoder = LabelEncoder()
arquivo['sex'] = label_encoder.fit_transform(arquivo['sex'])
arquivo['married'] = label_encoder.fit_transform(arquivo['married'])
arquivo['car'] = label_encoder.fit_transform(arquivo['car'])
arquivo['save_act'] = label_encoder.fit_transform(arquivo['save_act'])
arquivo['current_act'] = label_encoder.fit_transform(arquivo['current_act'])
arquivo['mortgage'] = label_encoder.fit_transform(arquivo['mortgage'])
arquivo['pep'] = label_encoder.fit_transform(arquivo['pep'])  # Variável alvo

# One-Hot Encoding para 'region'
arquivo = pd.get_dummies(arquivo, columns=['region'])
arquivo.head()
# Out:
#         id  age  sex   income  married  children  car  save_act  current_act  \
# 0  ID12101   48    0  17546.0        0         1    0         0            0
# 1  ID12102   40    1  30085.1        1         3    1         0            1
# 2  ID12103   51    0  16575.4        1         0    1         1            1
# 3  ID12104   23    0  20375.4        1         3    0         0            1
# 4  ID12105   57    0  50576.3        1         0    0         1            0
#
#    mortgage  pep  region_INNER_CITY  region_RURAL  region_SUBURBAN  \
# 0         0    1               True         False            False
# 1         1    0              False         False            False
# 2         0    0               True         False            False
# 3         0    0              False         False            False
# 4         0    0              False          True            False
#
#    region_TOWN
# 0        False
# 1         True
# 2        False
# 3         True
# 4        False

# %%
arquivo = arquivo.drop(columns=['id'])
arquivo.head()
# Out:
#    age  sex   income  married  children  car  save_act  current_act  mortgage  \
# 0   48    0  17546.0        0         1    0         0            0         0
# 1   40    1  30085.1        1         3    1         0            1         1
# 2   51    0  16575.4        1         0    1         1            1         0
# 3   23    0  20375.4        1         3    0         0            1         0
# 4   57    0  50576.3        1         0    0         1            0         0
#
#    pep  region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN
# 0    1               True         False            False        False
# 1    0              False         False            False         True
# 2    0               True         False            False        False
# 3    0              False         False            False         True
# 4    0              False          True            False        False

# %%
y = arquivo['pep']
X = arquivo.drop('pep', axis = 1)

# %%
from sklearn.model_selection import train_test_split

# Assuming x is your feature set and y is the target variable
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelo = ExtraTreesClassifier()
modelo.fit(x_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
resultado = modelo.score(x_test, y_test)
print ("Acurácia:", resultado)
# Out:
# Acurácia: 0.8166666666666667

# %%
# Adicionando a verificação da Precisão, Recall e F1-Score
from sklearn.metrics import precision_score, recall_score, f1_score

# Fazendo previsões no conjunto de teste
y_pred = modelo.predict(x_test)

# Calculando as métricas
precisao = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Precisão:", precisao)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precisão: 0.803921568627451
# Recall: 0.7735849056603774
# F1-score: 0.7884615384615384

# %%
from sklearn.metrics import confusion_matrix, classification_report

"""
Calculando e exibindo a matriz de confusão. A orientação padrão é a seguinte:
[0,0]: Verdadeiros Negativos (VN) - Previsões corretamente identificadas como negativas.
[0,1]: Falsos Positivos (FP) - Previsões incorretamente identificadas como positivas.
[1,0]: Falsos Negativos (FN) - Previsões incorretamente identificadas como negativas.
[1,1]: Verdadeiros Positivos (VP) - Previsões corretamente identificadas como positivas.
"""

conf_matrix = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(conf_matrix)
# Out:
# Matriz de Confusão:
# [[57 10]
#  [12 41]]

# %%
"""
Calculando e exibindo as métricas de classificação.
Se algumas classes têm muito mais amostras do que outras, isso pode influenciar o desempenho e confiabilidade do modelo.

O "support" refere-se à quantidade de ocorrências da classe específica no conjunto de dados, sendo útil para verificar desbalanceamentos.
A "macro avg" calcula a média aritmética das métricas (precisão, recall, F1-score) para cada classe, sem considerar o número de instâncias em cada classe (support).
A "weighted avg" calcula a média ponderada das métricas para cada classe, considerando o número de instâncias em cada classe (support).
"""
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84        67
#            1       0.80      0.77      0.79        53
#
#     accuracy                           0.82       120
#    macro avg       0.82      0.81      0.81       120
# weighted avg       0.82      0.82      0.82       120

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Prever as probabilidades para os dados de teste.
# Note que estamos interessados nas probabilidades da classe positiva (1), então usamos [:, 1].
y_probs = modelo.predict_proba(x_test)[:, 1]

# Calcular FPR, TPR, e limiares
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Calcular a AUC
roc_auc = auc(fpr, tpr)

# Plotar a curva ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
